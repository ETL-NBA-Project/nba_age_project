# %%
import pandas as pd
import numpy as np

# %%
pow_csv = "NBA_player_of_the_week.csv"
player_week_df = pd.read_csv(pow_csv, error_bad_lines=False)
player_week_df.head()
# Out:
#    Active season                  Player                  Team Conference  \
# 0              0  Micheal Ray Richardson       New Jersey Nets        NaN
# 1              0             Derek Smith  Los Angeles Clippers        NaN
# 2              0             Calvin Natt        Denver Nuggets        NaN
# 3              0     Kareem Abdul-Jabbar    Los Angeles Lakers        NaN
# 4              0              Larry Bird        Boston Celtics        NaN
#
#            Date Position Height  Weight  Age  Draft Year  Seasons in league  \
# 0  Apr 14, 1985       PG    6-5     189   29        1978                  6
# 1   Apr 7, 1985       SG    6-6     205   23        1982                  2
# 2   Apr 1, 1985        F    6-6     220   28        1979                  5
# 3  Mar 24, 1985        C    7-2     225   37        1969                 15
# 4  Mar 17, 1985       SF    6-9     220   28        1978                  5
#
#       Season  Season short  Real_value
# 0  1984-1985          1985         1.0
# 1  1984-1985          1985         1.0
# 2  1984-1985          1985         1.0
# 3  1984-1985          1985         1.0
# 4  1984-1985          1985         1.0

# %%
player_list = player_week_df["Player"].tolist()
player_list
# Out:
# ['Micheal Ray Richardson',
#  'Derek Smith',
#  'Calvin Natt',
#  'Kareem Abdul-Jabbar',
#  'Larry Bird',
#  'Darrell Griffith',
#  'Sleepy Floyd',
#  'Mark Aguirre',
#  'Magic Johnson',
#  'Dominique Wilkins',
#  'Tom McMillen',
#  'Michael Jordan',
#  'World B. Free',
#  'Isiah Thomas',
#  'Micheal Ray Richardson',
#  'Terry Cummings',
#  'Derek Smith',
#  'Orlando Woolridge',
#  'Jack Sikma',
#  'Bernard King',
#  'Moses Malone',
#  'Alex English',
#  'Larry Nance',
#  'Dominique Wilkins',
#  'Herb Williams',
#  'Charles Barkley',
#  'Adrian Dantley',
#  'Larry Bird',
#  'Magic Johnson',
#  'Charles Barkley',
#  'Sidney Moncrief',
#  'Larry Bird',
#  'Alex English',
#  'Charles Barkley',
#  'Larry Bird',
#  'Calvin Natt',
#  'Clyde Drexler',
#  'Dominique Wilkins',
#  'Larry Nance',
#  'Alvin Robertson',
#  'Jeff Ruland',
#  'Larry Bird',
#  'Alex English',
#  'Patrick Ewing',
#  'Buck Williams',
#  'Derek Smith',
#  'Julius Erving',
#  'Michael Jordan',
#  'Magic Johnson',
#  'Larry Smith',
#  'Magic Johnson',
#  'Karl Malone',
#  'Magic Johnson',
#  'Michael Jordan',
#  'Moses Malone',
#  'Magic Johnson',
#  'Fat Lever',
#  'Alex English',
#  'Otis Thorpe',
#  'Isiah Thomas',
#  'Larry Bird',
#  'Patrick Ewing',
#  'Magic Johnson',
#  'Dominique Wilkins',
#  'Tom Chambers',
#  'Hot Rod Williams',
#  'Alvin Robertson',
#  'Robert Parish',
#  'Michael Jordan',
#  'Karl Malone',
#  'Fat Lever',
#  'Harold Pressley',
#  'Michael Jordan',
#  'Michael Jordan',
#  'Charles Barkley',
#  'Clyde Drexler',
#  'Bobby Hansen',
#  'Roy Tarpley',
#  'John Stockton',
#  'Dominique Wilkins',
#  'Bernard King',
#  'Michael Jordan',
#  'Dominique Wilkins',
#  'Byron Scott',
#  'Karl Malone',
#  'Dominique Wilkins',
#  'Larry Nance',
#  'Magic Johnson',
#  'Clyde Drexler',
#  'Clyde Drexler',
#  'Xavier McDaniel',
#  'Larry Bird',
#  'Xavier McDaniel',
#  'Karl Malone',
#  'Clyde Drexler',
#  'Michael Jordan',
#  'Michael Jordan',
#  'Kevin Johnson',
#  'Isiah Thomas',
#  'Chuck Person',
#  'Patrick Ewing',
#  'Hakeem Olajuwon',
#  'Ron Harper',
#  'Tom Chambers',
#  'Chris Mullin',
#  'Michael Jordan',
#  'Dale Ellis',
#  'Magic Johnson',
#  'Clyde Drexler',
#  'Robert Parish',
#  'Michael Adams',
#  'Magic Johnson',
#  'Patrick Ewing',
#  'Michael Jordan',
#  'Hakeem Olajuwon',
#  'David Robinson',
#  'Magic Johnson',
#  'Charles Barkley',
#  'Michael Jordan',
#  'David Robinson',
#  'Kevin Johnson',
#  'Rony Seikaly',
#  'Hakeem Olajuwon',
#  'David Robinson',
#  'Tom Chambers',
#  'Tim Hardaway',
#  'Karl Malone',
#  'Alvin Robertson',
#  'Ron Harper',
#  'Terry Teagle',
#  'Karl Malone',
#  'Terry Cummings',
#  'Chris Mullin',
#  'Michael Jordan',
#  'Patrick Ewing',
#  'Clyde Drexler',
#  'John Stockton',
#  'Vern Fleming',
#  'Scott Skiles',
#  'Clyde Drexler',
#  'Magic Johnson',
#  'Clyde Drexler',
#  'Mitch Richmond',
#  'Kenny Smith',
#  'Dennis Scott',
#  'Gerald Wilkins',
#  'Reggie Miller',
#  'Lionel Simmons',
#  'Otis Thorpe',
#  'Michael Adams',
#  'Tim Hardaway',
#  'Bernard King',
#  'Dominique Wilkins',
#  'Ricky Pierce',
#  'Michael Jordan',
#  'Kevin Johnson',
#  'John Stockton',
#  'Michael Jordan',
#  'Charles Barkley',
#  'Clyde Drexler',
#  'Chris Mullin',
#  'Karl Malone',
#  'Reggie Lewis',
#  'Mookie Blaylock',
#  'Mark Jackson',
#  'Larry Johnson',
#  'Joe Dumars',
#  'Karl Malone',
#  'Danny Manning',
#  'Tim Hardaway',
#  'John Stockton',
#  'Larry Nance',
#  'Nick Anderson',
#  'Tim Hardaway',
#  'Michael Jordan',
#  'Patrick Ewing',
#  'Scottie Pippen',
#  'Pervis Ellison',
#  'Dennis Rodman',
#  'Jeff Malone',
#  'David Robinson',
#  'Kevin Willis',
#  'Brad Daugherty',
#  'Chris Mullin',
#  'Larry Johnson',
#  'Alonzo Mourning',
#  'Hakeem Olajuwon',
#  'Charles Barkley',
#  'Dikembe Mutombo',
#  'Patrick Ewing',
#  'Rumeal Robinson',
#  'Rony Seikaly',
#  'Hakeem Olajuwon',
#  'Larry Johnson',
#  'Nick Anderson',
#  'Karl Malone',
#  'Patrick Ewing',
#  'Hakeem Olajuwon',
#  'Shawn Kemp',
#  'David Robinson',
#  'Sean Elliott',
#  'Patrick Ewing',
#  'Charles Barkley',
#  'Drazen Petrovic',
#  'David Robinson',
#  'Michael Jordan',
#  "Shaquille O'Neal",
#  'David Robinson',
#  'Scottie Pippen',
#  'Dikembe Mutombo',
#  'Shawn Kemp',
#  'Kevin Willis',
#  'Hakeem Olajuwon',
#  'Joe Dumars',
#  'David Robinson',
#  'Shawn Kemp',
#  'David Robinson',
#  'David Robinson',
#  'Ron Harper',
#  'Kenny Anderson',
#  'Patrick Ewing',
#  'Chris Webber',
#  'Oliver Miller',
#  'Scottie Pippen',
#  'Karl Malone',
#  "Shaquille O'Neal",
#  'David Robinson',
#  'Glen Rice',
#  'Charles Barkley',
#  'Hakeem Olajuwon',
#  'Karl Malone',
#  'Dikembe Mutombo',
#  'Clyde Drexler',
#  'David Robinson',
#  'Vlade Divac',
#  'Jason Kidd',
#  'Rik Smits',
#  "Shaquille O'Neal",
#  'Rod Strickland',
#  'Charles Barkley',
#  'Hakeem Olajuwon',
#  'John Stockton',
#  'Patrick Ewing',
#  'Larry Johnson',
#  'Gary Payton',
#  'Hakeem Olajuwon',
#  'Cedric Ceballos',
#  'Karl Malone',
#  'Jamal Mashburn',
#  "Shaquille O'Neal",
#  'Penny Hardaway',
#  'Elliot Perry',
#  'Tim Hardaway',
#  'Dennis Scott',
#  'Juwan Howard',
#  'Kevin Johnson',
#  'Arvydas Sabonis',
#  'Chris Gatling',
#  'Grant Hill',
#  'Michael Jordan',
#  "Shaquille O'Neal",
#  'Hakeem Olajuwon',
#  'Shawn Kemp',
#  'Armen Gilliam',
#  'Jason Kidd',
#  'Reggie Miller',
#  'Michael Jordan',
#  'David Robinson',
#  'Cliff Robinson',
#  'Karl Malone',
#  'Michael Jordan',
#  'Scottie Pippen',
#  'Dikembe Mutombo',
#  'Terrell Brandon',
#  'Shawn Kemp',
#  'Cedric Ceballos',
#  'Penny Hardaway',
#  'Chris Webber',
#  'Allen Iverson',
#  'Grant Hill',
#  'Kevin Johnson',
#  'Karl Malone',
#  'Karl Malone',
#  'Patrick Ewing',
#  'Loy Vaught',
#  'Scottie Pippen',
#  'Alonzo Mourning',
#  'Glen Rice',
#  'Mitch Richmond',
#  'Grant Hill',
#  'Glenn Robinson',
#  'Glen Rice',
#  'Tim Hardaway',
#  'Terrell Brandon',
#  "Shaquille O'Neal",
#  'Terry Mills',
#  'Dikembe Mutombo',
#  'Charles Barkley',
#  'Karl Malone',
#  'Dale Ellis',
#  'Hakeem Olajuwon',
#  'Jason Kidd',
#  'Sam Cassell',
#  'Michael Jordan',
#  'Alonzo Mourning',
#  "Shaquille O'Neal",
#  'Jason Kidd',
#  'Karl Malone',
#  'Tim Duncan',
#  'Nick Anderson',
#  'Karl Malone',
#  'David Robinson',
#  'Jayson Williams',
#  'Allen Iverson',
#  'Steve Smith',
#  'Rik Smits',
#  'David Robinson',
#  'Michael Jordan',
#  'Glen Rice',
#  'Wesley Person',
#  'Karl Malone',
#  'Michael Jordan',
#  "Shaquille O'Neal",
#  'Dikembe Mutombo',
#  'Grant Hill',
#  'Chris Webber',
#  'Jason Kidd',
#  'Karl Malone',
#  'Kevin Garnett',
#  'Darrell Armstrong',
#  'Vince Carter',
#  'Alonzo Mourning',
#  'Tim Duncan',
#  'Antonio McDyess',
#  'Stephon Marbury',
#  'Gary Payton',
#  'Dikembe Mutombo',
#  'Kobe Bryant',
#  'Alonzo Mourning',
#  'Tim Duncan',
#  'Kevin Garnett',
#  'Jalen Rose',
#  "Shaquille O'Neal",
#  'Karl Malone',
#  'Vince Carter',
#  "Shaquille O'Neal",
#  'Michael Finley',
#  'Dikembe Mutombo',
#  'Steve Francis',
#  'Chris Webber',
#  'Grant Hill',
#  'Chris Webber',
#  'Kevin Garnett',
#  'Jason Kidd',
#  'Alonzo Mourning',
#  "Shaquille O'Neal",
#  'Tim Duncan',
#  'Vince Carter',
#  'Kevin Garnett',
#  'Sam Cassell',
#  'Ray Allen',
#  "Shaquille O'Neal",
#  'Jason Kidd',
#  'Paul Pierce',
#  'Cuttino Mobley',
#  'Derek Anderson',
#  'Vince Carter',
#  'Shawn Marion',
#  'Allen Iverson',
#  'Darrell Armstrong',
#  'Tim Duncan',
#  'Chris Webber',
#  'Steve Francis',
#  'Allen Iverson',
#  'Aaron McKie',
#  'Kobe Bryant',
#  'Glenn Robinson',
#  'Chris Webber',
#  'Antonio McDyess',
#  'Baron Davis',
#  'Kevin Garnett',
#  'Stephon Marbury',
#  'Karl Malone',
#  'John Stockton',
#  'Paul Pierce',
#  'Tim Duncan',
#  'Ben Wallace',
#  'Shawn Marion',
#  'Jason Kidd',
#  'Tim Duncan',
#  'Tracy McGrady',
#  'Tim Duncan',
#  'Kurt Thomas',
#  "Shaquille O'Neal",
#  'Allen Iverson',
#  'Rasheed Wallace',
#  'Ben Wallace',
#  "Shaquille O'Neal",
#  'Andre Miller',
#  'Karl Malone',
#  'Jason Kidd',
#  "Shaquille O'Neal",
#  'Allen Iverson',
#  'Dirk Nowitzki',
#  'Allen Iverson',
#  'Kobe Bryant',
#  'Ray Allen',
#  'Kevin Garnett',
#  'Eddie Jones',
#  'Chris Webber',
#  'Jason Kidd',
#  'Tim Duncan',
#  "Jermaine O'Neal",
#  'Gary Payton',
#  'Richard Hamilton',
#  'Steve Nash',
#  'Andre Miller',
#  'Elton Brand',
#  'Paul Pierce',
#  'Stephon Marbury',
#  'Shareef Abdur-Rahim',
#  'Tim Duncan',
#  'Allen Iverson',
#  'Kevin Garnett',
#  'Vince Carter',
#  'Tim Duncan',
#  'Ray Allen',
#  'Kobe Bryant',
#  'Tracy McGrady',
#  'Shawn Marion',
#  'Jason Kidd',
#  "Shaquille O'Neal",
#  'Richard Jefferson',
#  'Tim Duncan',
#  'Ben Wallace',
#  'Peja Stojakovic',
#  'Allen Iverson',
#  'Steve Francis',
#  'Tracy McGrady',
#  "Shaquille O'Neal",
#  'Michael Jordan',
#  'Ray Allen',
#  'Tracy McGrady',
#  'Kobe Bryant',
#  'Allan Houston',
#  'Tim Duncan',
#  'Chauncey Billups',
#  'Kobe Bryant',
#  'Paul Pierce',
#  'Tim Duncan',
#  'Antoine Walker',
#  'Steve Francis',
#  "Jermaine O'Neal",
#  'Kobe Bryant',
#  'Stephon Marbury',
#  'Michael Jordan',
#  'Dirk Nowitzki',
#  'Lucious Harris',
#  'Tim Duncan',
#  'Jason Kidd',
#  'Tim Duncan',
#  'Antoine Walker',
#  'Chris Webber',
#  'Paul Pierce',
#  'Kobe Bryant',
#  'Allen Iverson',
#  'Stephon Marbury',
#  'Allen Iverson',
#  'Kevin Garnett',
#  'Metta World Peace',
#  'Rashard Lewis',
#  'Jerry Stackhouse',
#  'Dirk Nowitzki',
#  'Glenn Robinson',
#  'Kobe Bryant',
#  'Jamaal Magloire',
#  'Carmelo Anthony',
#  'Richard Jefferson',
#  'Dirk Nowitzki',
#  'Metta World Peace',
#  'Kobe Bryant',
#  'Vince Carter',
#  "Shaquille O'Neal",
#  'Zydrunas Ilgauskas',
#  'Carmelo Anthony',
#  'Lamar Odom',
#  'Yao Ming',
#  'Ben Wallace',
#  'Andrei Kirilenko',
#  'Dwyane Wade',
#  'Kobe Bryant',
#  'Kenyon Martin',
#  'Tim Duncan',
#  'Jason Kidd',
#  'Kevin Garnett',
#  'Carlos Boozer',
#  'Kevin Garnett',
#  'Stephon Marbury',
#  'Michael Finley',
#  'Paul Pierce',
#  'Ray Allen',
#  'Ben Wallace',
#  'Elton Brand',
#  'Jason Kidd',
#  'Sam Cassell',
#  'Tracy McGrady',
#  'Kevin Garnett',
#  'Paul Pierce',
#  'Peja Stojakovic',
#  'Vince Carter',
#  "Shaquille O'Neal",
#  'Dikembe Mutombo',
#  'Voshon Lenard',
#  'Chauncey Billups',
#  'Kevin Garnett',
#  'Allen Iverson',
#  'Quentin Richardson',
#  'Metta World Peace',
#  'Andrei Kirilenko',
#  'Baron Davis',
#  'Rashard Lewis',
#  'Jason Kidd',
#  'Tracy McGrady',
#  'Vince Carter',
#  'Baron Davis',
#  'Reggie Miller',
#  'Baron Davis',
#  'Allen Iverson',
#  'Ray Allen',
#  'Chauncey Billups',
#  'Jason Richardson',
#  'Paul Pierce',
#  'Tracy McGrady',
#  'Allen Iverson',
#  'Marcus Camby',
#  'Jalen Rose',
#  'Mike Bibby',
#  'Allen Iverson',
#  'Steve Nash',
#  'Paul Pierce',
#  'Tracy McGrady',
#  'Vince Carter',
#  'Brad Miller',
#  'LeBron James',
#  'Jason Terry',
#  'Larry Hughes',
#  'Tracy McGrady',
#  'Chris Bosh',
#  'Bruce Bowen',
#  'Stephon Marbury',
#  'Pau Gasol',
#  'Allen Iverson',
#  'Steve Nash',
#  "Shaquille O'Neal",
#  'Shawn Marion',
#  'Richard Jefferson',
#  "Amar'e Stoudemire",
#  'Gilbert Arenas',
#  'Dirk Nowitzki',
#  'LeBron James',
#  'Shawn Marion',
#  'Grant Hill',
#  "Amar'e Stoudemire",
#  'LeBron James',
#  'Ray Allen',
#  'Dwyane Wade',
#  'Kevin Garnett',
#  'Ben Gordon',
#  'Kobe Bryant',
#  'Jamal Crawford',
#  'Chris Wilcox',
#  'LeBron James',
#  'Yao Ming',
#  'LeBron James',
#  'Pau Gasol',
#  'LeBron James',
#  'Carmelo Anthony',
#  'Paul Pierce',
#  'Mike Bibby',
#  'Allen Iverson',
#  'Pau Gasol',
#  'Gilbert Arenas',
#  'Yao Ming',
#  'Gilbert Arenas',
#  'Tony Parker',
#  'Chris Bosh',
#  'Chris Paul',
#  'LeBron James',
#  'Elton Brand',
#  'Richard Hamilton',
#  'Kobe Bryant',
#  'Allen Iverson',
#  'Kevin Garnett',
#  'Mike James',
#  'Steve Nash',
#  'Dwyane Wade',
#  'Shawn Marion',
#  'Vince Carter',
#  'Kobe Bryant',
#  'Joe Johnson',
#  'Kobe Bryant',
#  'Allen Iverson',
#  'Elton Brand',
#  'Dwyane Wade',
#  'Baron Davis',
#  'Gerald Wallace',
#  'Steve Nash',
#  'LeBron James',
#  'Elton Brand',
#  'Gilbert Arenas',
#  'Marcus Camby',
#  'T.J. Ford',
#  'Kobe Bryant',
#  'Ben Gordon',
#  'Tracy McGrady',
#  'Gerald Wallace',
#  'Tim Duncan',
#  'Chris Bosh',
#  'Yao Ming',
#  'Gerald Wallace',
#  'Kobe Bryant',
#  'Jason Kidd',
#  'Kobe Bryant',
#  'LeBron James',
#  'Manu Ginobili',
#  'Al Jefferson',
#  'Kevin Martin',
#  'Vince Carter',
#  "Amar'e Stoudemire",
#  'Dwyane Wade',
#  'Carmelo Anthony',
#  'Dwyane Wade',
#  'Mehmet Okur',
#  'Ben Gordon',
#  'Steve Nash',
#  'Caron Butler',
#  'Steve Nash',
#  'Dwyane Wade',
#  'Dirk Nowitzki',
#  'Gilbert Arenas',
#  'Kevin Garnett',
#  'Michael Redd',
#  'Josh Howard',
#  'Mo Williams',
#  'Josh Howard',
#  'Gilbert Arenas',
#  'Carlos Boozer',
#  'Gilbert Arenas',
#  'Steve Nash',
#  'Michael Redd',
#  'Carmelo Anthony',
#  'Dwight Howard',
#  'Carmelo Anthony',
#  'LeBron James',
#  'Dirk Nowitzki',
#  'Joe Johnson',
#  'Yao Ming',
#  'Allen Iverson',
#  'Carlos Boozer',
#  'Kevin Garnett',
#  'Allen Iverson',
#  'Joe Johnson',
#  'Kobe Bryant',
#  'Jason Richardson',
#  'Carmelo Anthony',
#  'Kevin Garnett',
#  'Chris Paul',
#  'Antawn Jamison',
#  "Amar'e Stoudemire",
#  'Jason Richardson',
#  'Tracy McGrady',
#  'Andre Miller',
#  'Kobe Bryant',
#  'LeBron James',
#  'Manu Ginobili',
#  'Andre Miller',
#  "Amar'e Stoudemire",
#  'Hedo Turkoglu',
#  'Brad Miller',
#  'Hedo Turkoglu',
#  'Al Jefferson',
#  'Gerald Wallace',
#  'Baron Davis',
#  'Chris Bosh',
#  'Kobe Bryant',
#  'LeBron James',
#  'Allen Iverson',
#  'Paul Pierce',
#  'Chris Paul',
#  'Joe Johnson',
#  'Carmelo Anthony',
#  'Paul Pierce',
#  'Brandon Roy',
#  'Josh Smith',
#  'Brandon Roy',
#  'Dwight Howard',
#  'Stephen Jackson',
#  'LeBron James',
#  'Tony Parker',
#  'Dwight Howard',
#  'Allen Iverson',
#  'Kevin Garnett',
#  'Yao Ming',
#  'Danny Granger',
#  'Tracy McGrady',
#  'Ben Gordon',
#  'Brandon Roy',
#  'Dwight Howard',
#  'Jason Kidd',
#  'Dwight Howard',
#  'Tony Parker',
#  'LeBron James',
#  'Chris Paul',
#  'LeBron James',
#  'Kobe Bryant',
#  'Dwyane Wade',
#  'Deron Williams',
#  'Devin Harris',
#  'David West',
#  'Dwight Howard',
#  'Pau Gasol',
#  'LeBron James',
#  'Pau Gasol',
#  'David Lee',
#  'Tony Parker',
#  'LeBron James',
#  'Andrew Bynum',
#  'Jameer Nelson',
#  'Chris Paul',
#  'Dwight Howard',
#  'Kobe Bryant',
#  'Rodney Stuckey',
#  'Al Jefferson',
#  'LeBron James',
#  'Kobe Bryant',
#  'Jameer Nelson',
#  'Chris Paul',
#  'Al Harrington',
#  'Tim Duncan',
#  'Dwyane Wade',
#  'Dirk Nowitzki',
#  'Devin Harris',
#  'Brandon Roy',
#  'Dwyane Wade',
#  'Dirk Nowitzki',
#  'LeBron James',
#  'Chauncey Billups',
#  'LeBron James',
#  "Amar'e Stoudemire",
#  'Chris Bosh',
#  'Chris Paul',
#  'Dwight Howard',
#  'Dirk Nowitzki',
#  'Chris Bosh',
#  'Kevin Durant',
#  'Dwyane Wade',
#  'Manu Ginobili',
#  'Paul Pierce',
#  'Pau Gasol',
#  'Andrew Bogut',
#  'Brandon Roy',
#  'Dwyane Wade',
#  'Dirk Nowitzki',
#  'LeBron James',
#  'Dirk Nowitzki',
#  'Dwight Howard',
#  'Carlos Boozer',
#  'LeBron James',
#  'Russell Westbrook',
#  'Chris Bosh',
#  'Kevin Durant',
#  'LeBron James',
#  'Chauncey Billups',
#  'Stephen Jackson',
#  'Carmelo Anthony',
#  'LeBron James',
#  'Chris Kaman',
#  'Derrick Rose',
#  'Kevin Durant',
#  'LeBron James',
#  'Kobe Bryant',
#  'Dwight Howard',
#  'Kobe Bryant',
#  'Rodney Stuckey',
#  'Deron Williams',
#  'Kevin Garnett',
#  'Carlos Boozer',
#  'Gerald Wallace',
#  'Tim Duncan',
#  'LeBron James',
#  'Kobe Bryant',
#  'Brandon Jennings',
#  'Dirk Nowitzki',
#  'Joe Johnson',
#  'Chris Kaman',
#  'Dwight Howard',
#  'Carmelo Anthony',
#  'Carmelo Anthony',
#  'Kevin Durant',
#  'Carmelo Anthony',
#  'Zach Randolph',
#  'Dwight Howard',
#  'Kobe Bryant',
#  'LeBron James',
#  'Kyle Lowry',
#  'Dwyane Wade',
#  'Tony Parker',
#  'Paul Pierce',
#  'Russell Westbrook',
#  'Dwight Howard',
#  'Kevin Martin',
#  'Dwight Howard',
#  'LaMarcus Aldridge',
#  'LeBron James',
#  'Kevin Durant',
#  'LeBron James',
#  'Zach Randolph',
#  'Dwight Howard',
#  'LaMarcus Aldridge',
#  'Derrick Rose',
#  'Russell Westbrook',
#  'LeBron James',
#  'Zach Randolph',
#  'Dwyane Wade',
#  'Chauncey Billups',
#  'LeBron James',
#  'Monta Ellis',
#  'Paul Pierce',
#  'Tony Parker',
#  'Dwyane Wade',
#  'Dirk Nowitzki',
#  "Amar'e Stoudemire",
#  'Russell Westbrook',
#  'Dwight Howard',
#  'Dirk Nowitzki',
#  "Amar'e Stoudemire",
#  'Russell Westbrook',
#  'Derrick Rose',
#  'Deron Williams',
#  'Dwight Howard',
#  'Chris Paul',
#  'Rajon Rondo',
#  'Pau Gasol',
#  'LeBron James',
#  'Al Jefferson',
#  'Kevin Garnett',
#  'Andrew Bynum',
#  'LeBron James',
#  'Goran Dragic',
#  'Paul Pierce',
#  'Chris Paul',
#  'Joe Johnson',
#  'Kevin Durant',
#  'Drew Gooden',
#  'Andrew Bynum',
#  'Ersan Ilyasova',
#  'Monta Ellis',
#  'Derrick Rose',
#  'Ty Lawson',
#  'LeBron James',
#  'Kevin Durant',
#  'Jeremy Lin',
#  'Russell Westbrook',
#  'Paul Pierce',
#  'Tony Parker',
#  'LeBron James',
#  'Russell Westbrook',
#  'Dwight Howard',
#  'Marc Gasol',
#  'Derrick Rose',
#  'Kobe Bryant',
#  'LeBron James',
#  'Kobe Bryant',
#  'LeBron James',
#  'Kevin Durant',
#  'Carmelo Anthony',
#  'Kobe Bryant',
#  'Carmelo Anthony',
#  'Nikola Pekovic',
#  'J.R. Smith',
#  'Al Jefferson',
#  'LeBron James',
#  'James Harden',
#  'John Wall',
#  'LaMarcus Aldridge',
#  'Dwyane Wade',
#  'Kobe Bryant',
#  'Monta Ellis',
#  'Ty Lawson',
#  'LeBron James',
#  'Kobe Bryant',
#  'LeBron James',
#  'Russell Westbrook',
#  'Nate Robinson',
#  'David Lee',
#  'Kyrie Irving',
#  'Tony Parker',
#  'Carlos Boozer',
#  'Kevin Durant',
#  'Brandon Jennings',
#  'Kevin Durant',
#  'Carmelo Anthony',
#  'James Harden',
#  'Monta Ellis',
#  'Greivis Vasquez',
#  'LeBron James',
#  'Chris Paul',
#  'Paul George',
#  'David Lee',
#  'Josh Smith',
#  'Blake Griffin',
#  'Carmelo Anthony',
#  'Kevin Durant',
#  'Al Horford',
#  'Tim Duncan',
#  'LeBron James',
#  'Kevin Durant',
#  'LeBron James',
#  'Kenneth Faried',
#  'Brandon Jennings',
#  'James Harden',
#  'Jeff Teague',
#  'Monta Ellis',
#  'Al Jefferson',
#  'Dirk Nowitzki',
#  'Nikola Vucevic',
#  'Tim Duncan',
#  'Joe Johnson',
#  'Kevin Durant',
#  'Al Jefferson',
#  'Blake Griffin',
#  'Carmelo Anthony',
#  'James Harden',
#  'John Wall',
#  'James Harden',
#  'Kemba Walker',
#  'Kevin Love',
#  'Jared Sullinger',
#  'Kevin Durant',
#  'Kyle Lowry',
#  'Goran Dragic',
#  'Paul Millsap',
#  'Kevin Durant',
#  'Paul George',
#  'Kevin Durant',
#  'Carmelo Anthony',
#  'DeMarcus Cousins',
#  'Thaddeus Young',
#  'David Lee',
#  'Chris Bosh',
#  'Kevin Durant',
#  'Dwyane Wade',
#  'Blake Griffin',
#  'Kyrie Irving',
#  'LaMarcus Aldridge',
#  'Jordan Crawford',
#  'LaMarcus Aldridge',
#  'LeBron James',
#  'Kevin Durant',
#  'John Wall',
#  'LaMarcus Aldridge',
#  'LeBron James',
#  'Blake Griffin',
#  'Paul George',
#  'Markieff Morris',
#  'Michael Carter-Williams',
#  'Kevin Love',
#  'Isaiah Thomas',
#  'Tim Duncan',
#  'Brook Lopez',
#  'James Harden',
#  'Brook Lopez',
#  'Stephen Curry',
#  'Dwyane Wade',
#  'Chris Paul',
#  'Kyrie Irving',
#  'Anthony Davis',
#  'Mo Williams',
#  'Russell Westbrook',
#  'Isaiah Thomas',
#  'Damian Lillard',
#  'Giannis Antetokounmpo',
#  'Russell Westbrook',
#  'Kyrie Irving',
#  'Zach Randolph',
#  'LeBron James',
#  'Klay Thompson',
#  'Al Horford',
#  'Mo Williams',
#  'Kemba Walker',
#  'Klay Thompson',
#  'Jeff Teague',
#  'Kevin Durant',
#  'Jimmy Butler',
#  'James Harden',
#  'Al Horford',
#  'LaMarcus Aldridge',
#  'John Wall',
#  'James Harden',
#  'Kyle Lowry',
#  ...]

# %%
stats_csv = "NBA Players - Basic Season Stats (1950-2017).csv"
player_stats_df = pd.read_excel(stats_csv)
player_stats_df.head()
# Out:
#          #  Season Start     Player Name Player Salary in $ Pos   Age   Tm  \
# 0  11999.0        1995.0      A.C. Green            6473000  SF  31.0  PHO
# 1  12107.0        1995.0     Aaron McKie             845000  SG  22.0  POR
# 2  12232.0        1995.0   Aaron Swinson                NaN  SF  24.0  PHO
# 3  12268.0        1995.0  Aaron Williams                NaN  PF  23.0  MIL
# 4  11953.0        1995.0       Acie Earl            1040000   C  24.0  BOS
#
#       G    GS      MP  ...      FT%    ORB    DRB    TRB    AST   STL   BLK  \
# 0  82.0  52.0  2687.0  ...    0.732  194.0  475.0  669.0  127.0  55.0  31.0
# 1  45.0  20.0   827.0  ...    0.685   35.0   94.0  129.0   89.0  36.0  16.0
# 2   9.0   0.0    51.0  ...    0.800    3.0    5.0    8.0    3.0   1.0   0.0
# 3  15.0   0.0    72.0  ...    0.667    5.0   14.0   19.0    0.0   2.0   6.0
# 4  30.0   3.0   208.0  ...    0.483   19.0   26.0   45.0    2.0   6.0   8.0
#
#      TOV     PF    PTS
# 0  114.0  146.0  916.0
# 1   39.0   97.0  293.0
# 2    5.0    8.0   24.0
# 3    7.0   14.0   24.0
# 4   14.0   39.0   66.0
#
# [5 rows x 54 columns]

# %%
player_stats_df = player_stats_df[player_stats_df['Player Name'].isin(player_list)]
player_stats_df.head()
# Out:
#           #  Season Start    Player Name Player Salary in $ Pos   Age   Tm  \
# 1   12107.0        1995.0    Aaron McKie             845000  SG  22.0  POR
# 10  12027.0        1995.0  Allan Houston                NaN  SG  23.0  DET
# 28  11990.0        1995.0  Armen Gilliam            1920000  PF  30.0  NJN
# 54  12269.0        1995.0  Buck Williams            3400000  PF  34.0  POR
# 56  12200.0        1995.0    Byron Scott            1650000  PG  33.0  IND
#
#        G    GS      MP   ...      FT%    ORB    DRB    TRB    AST   STL   BLK  \
# 1   45.0  20.0   827.0   ...    0.685   35.0   94.0  129.0   89.0  36.0  16.0
# 10  76.0  39.0  1996.0   ...    0.860   29.0  138.0  167.0  164.0  61.0  14.0
# 28  82.0  30.0  2472.0   ...    0.770  192.0  421.0  613.0   99.0  67.0  89.0
# 54  82.0  82.0  2422.0   ...    0.673  251.0  418.0  669.0   78.0  67.0  69.0
# 56  80.0   1.0  1528.0   ...    0.850   18.0  133.0  151.0  108.0  61.0  13.0
#
#       TOV     PF     PTS
# 1    39.0   97.0   293.0
# 10  113.0  182.0  1101.0
# 28  152.0  171.0  1212.0
# 54  119.0  254.0   757.0
# 56  119.0  123.0   802.0
#
# [5 rows x 54 columns]

# %%
player_stats_df.columns
# player_stats_df
# print(player_stats_df['AST%'])

# (Tm, Season Start, Age, Player Name, Pos, MP, PER, FG%, FT%, TS%, PTS, ORB, DRB, STL, BLK, TOV)
# Out:
# Index(['#', 'Season Start', 'Player Name', 'Player Salary in $', 'Pos', 'Age',
#        'Tm', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%',
#        'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS',
#        'WS', 'WS/48', 'blank2', 'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA',
#        'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA',
#        'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
new_stats_df = player_stats_df[['Tm', 'Season Start', 'Age', 
                               'Player Name', 'Pos', 'G', 'MP', 'PER', 
                               'FG%', 'FT%', 'TS%', 'PTS', 'ORB', 
                               'DRB', 'STL', 'BLK', 'TOV']].reset_index()
new_stats_df = new_stats_df.drop('index', axis = 1)


new_stats_df.head()
# Out:
#     Tm  Season Start   Age    Player Name Pos     G      MP   PER    FG%  \
# 0  POR        1995.0  22.0    Aaron McKie  SG  45.0   827.0  13.3  0.444
# 1  DET        1995.0  23.0  Allan Houston  SG  76.0  1996.0  16.4  0.463
# 2  NJN        1995.0  30.0  Armen Gilliam  PF  82.0  2472.0  18.1  0.503
# 3  POR        1995.0  34.0  Buck Williams  PF  82.0  2422.0  13.6  0.512
# 4  IND        1995.0  33.0    Byron Scott  PG  80.0  1528.0  15.8  0.455
#
#      FT%    TS%     PTS    ORB    DRB   STL   BLK    TOV
# 0  0.685  0.500   293.0   35.0   94.0  36.0  16.0   39.0
# 1  0.860  0.589  1101.0   29.0  138.0  61.0  14.0  113.0
# 2  0.770  0.562  1212.0  192.0  421.0  67.0  89.0  152.0
# 3  0.673  0.545   757.0  251.0  418.0  67.0  69.0  119.0
# 4  0.850  0.587   802.0   18.0  133.0  61.0  13.0  119.0

# %%
new_stats_df['PPG'] = round(new_stats_df['PTS']/new_stats_df["G"], 2)
new_stats_df['ORB/G'] = round(new_stats_df['ORB']/new_stats_df["G"], 2)
new_stats_df['DRB/G'] = round(new_stats_df['DRB']/new_stats_df["G"], 2)
new_stats_df['SPG'] = round(new_stats_df['STL']/new_stats_df["G"], 2)
new_stats_df['BPG'] = round(new_stats_df['BLK']/new_stats_df["G"], 2)
new_stats_df['TOV/G'] = round(new_stats_df['TOV']/new_stats_df["G"], 2)

final_df = new_stats_df[['Tm', 'Season Start', 'Age', 
                        'Player Name', 'Pos', 'G', 
                        'MP', 'PER', 'FG%', 'FT%', 'TS%',
                        'PPG', 'ORB/G', 'DRB/G', 'SPG',
                        'BPG', 'TOV/G']]
final_df = final_df.sort_values(['Player Name','Season Start'])
final

final_df.head(100)
# Out:
#        Tm  Season Start   Age        Player Name    Pos     G      MP   PER  \
# 0     POR        1995.0  22.0        Aaron McKie     SG  45.0   827.0  13.3
# 67    POR        1996.0  23.0        Aaron McKie     SG  81.0  2259.0  13.4
# 146   TOT        1997.0  24.0        Aaron McKie     SG  83.0  1625.0  12.1
# 147   POR        1997.0  24.0        Aaron McKie     SG  41.0   775.0   9.1
# 148   DET        1997.0  24.0        Aaron McKie     SG  42.0   850.0  14.8
# 246   TOT        1998.0  25.0        Aaron McKie  SG-SF  81.0  1813.0   8.6
# 247   DET        1998.0  25.0        Aaron McKie     SF  24.0   472.0  10.1
# 248   PHI        1998.0  25.0        Aaron McKie     SG  57.0  1341.0   8.1
# 339   PHI        1999.0  26.0        Aaron McKie     SG  50.0   959.0  11.4
# 433   PHI        2000.0  27.0        Aaron McKie     SG  82.0  1952.0  13.2
# 526   PHI        2001.0  28.0        Aaron McKie     SG  76.0  2394.0  15.1
# 625   PHI        2002.0  29.0        Aaron McKie     SG  48.0  1471.0  15.8
# 722   PHI        2003.0  30.0        Aaron McKie     SF  80.0  2374.0  13.7
# 816   PHI        2004.0  31.0        Aaron McKie     SF  75.0  2112.0  13.9
# 929   PHI        2005.0  32.0        Aaron McKie     SG  68.0  1118.0   8.4
# 1048  LAL        2006.0  33.0        Aaron McKie     PG  14.0   121.0   6.1
# 1160  LAL        2007.0  34.0        Aaron McKie     SF  10.0   131.0   7.5
# 340   IND        1999.0  18.0      Al Harrington     PF  21.0   160.0   6.4
# 434   IND        2000.0  19.0      Al Harrington     PF  50.0   854.0  10.8
# 527   IND        2001.0  20.0      Al Harrington     PF  78.0  1892.0  10.2
# 626   IND        2002.0  21.0      Al Harrington     PF  44.0  1313.0  14.3
# 723   IND        2003.0  22.0      Al Harrington     SF  82.0  2467.0  12.4
# 817   IND        2004.0  23.0      Al Harrington     PF  79.0  2441.0  14.9
# 930   ATL        2005.0  24.0      Al Harrington     SF  66.0  2550.0  14.4
# 1049  ATL        2006.0  25.0      Al Harrington     PF  76.0  2782.0  16.0
# 1161  TOT        2007.0  26.0      Al Harrington     PF  78.0  2563.0  14.8
# 1162  IND        2007.0  26.0      Al Harrington     PF  36.0  1208.0  13.4
# 1163  GSW        2007.0  26.0      Al Harrington     PF  42.0  1355.0  16.1
# 1277  GSW        2008.0  27.0      Al Harrington      C  81.0  2190.0  15.6
# 1409  TOT        2009.0  28.0      Al Harrington     PF  73.0  2546.0  15.9
# ...   ...           ...   ...                ...    ...   ...     ...   ...
# 932   NYK        2005.0  33.0      Allan Houston     SG  20.0   532.0  12.5
# 69    TOR        1996.0  33.0    Alvin Robertson     SG  77.0  2478.0  12.7
# 725   PHO        2003.0  20.0  Amar'e Stoudemire     PF  82.0  2570.0  16.2
# 819   PHO        2004.0  21.0  Amar'e Stoudemire     PF  55.0  2025.0  19.8
# 933   PHO        2005.0  22.0  Amar'e Stoudemire      C  80.0  2889.0  26.6
# 1051  PHO        2006.0  23.0  Amar'e Stoudemire      C   3.0    50.0  17.8
# 1165  PHO        2007.0  24.0  Amar'e Stoudemire      C  82.0  2689.0  23.1
# 1280  PHO        2008.0  25.0  Amar'e Stoudemire      C  79.0  2677.0  27.6
# 1414  PHO        2009.0  26.0  Amar'e Stoudemire     PF  53.0  1948.0  20.3
# 1549  PHO        2010.0  27.0  Amar'e Stoudemire     PF  82.0  2838.0  22.6
# 1683  NYK        2011.0  28.0  Amar'e Stoudemire      C  78.0  2870.0  22.7
# 1840  NYK        2012.0  29.0  Amar'e Stoudemire     PF  47.0  1543.0  17.7
# 1976  NYK        2013.0  30.0  Amar'e Stoudemire     PF  29.0   682.0  22.1
# 2103  NYK        2014.0  31.0  Amar'e Stoudemire      C  65.0  1466.0  18.8
# 2231  TOT        2015.0  32.0  Amar'e Stoudemire     PF  59.0  1245.0  20.3
# 2232  NYK        2015.0  32.0  Amar'e Stoudemire     PF  36.0   865.0  19.5
# 2233  DAL        2015.0  32.0  Amar'e Stoudemire     PF  23.0   380.0  22.3
# 2373  MIA        2016.0  33.0  Amar'e Stoudemire      C  52.0   762.0  17.3
# 1977  DET        2013.0  19.0     Andre Drummond      C  60.0  1243.0  21.6
# 2104  DET        2014.0  20.0     Andre Drummond      C  81.0  2619.0  22.6
# 2234  DET        2015.0  21.0     Andre Drummond      C  82.0  2502.0  21.4
# 2374  DET        2016.0  22.0     Andre Drummond      C  81.0  2666.0  21.2
# 2496  DET        2017.0  23.0     Andre Drummond      C  81.0  2409.0  20.9
# 436   CLE        2000.0  23.0       Andre Miller     PG  82.0  2093.0  17.9
# 529   CLE        2001.0  24.0       Andre Miller     PG  82.0  2848.0  20.1
# 628   CLE        2002.0  25.0       Andre Miller     PG  81.0  3023.0  21.8
# 726   LAC        2003.0  26.0       Andre Miller     PG  80.0  2913.0  15.2
# 820   DEN        2004.0  27.0       Andre Miller     PG  82.0  2838.0  18.8
# 934   DEN        2005.0  28.0       Andre Miller     PG  82.0  2852.0  16.5
# 1052  DEN        2006.0  29.0       Andre Miller     PG  82.0  2937.0  16.4
#
#         FG%    FT%    TS%    PPG  ORB/G  DRB/G   SPG   BPG  TOV/G
# 0     0.444  0.685  0.500   6.51   0.78   2.09  0.80  0.36   0.87
# 67    0.467  0.764  0.534  10.67   1.06   2.69  1.14  0.26   1.67
# 146   0.411  0.836  0.524   5.22   0.48   2.18  0.93  0.27   1.08
# 147   0.340  0.837  0.479   4.15   0.32   1.95  0.83  0.37   1.17
# 148   0.464  0.836  0.558   6.26   0.64   2.40  1.02  0.17   1.00
# 246   0.365  0.764  0.410   4.10   0.72   2.14  1.25  0.16   0.94
# 247   0.413  0.870  0.478   4.54   1.00   1.83  0.96  0.04   1.00
# 248   0.347  0.688  0.383   3.91   0.60   2.26  1.37  0.21   0.91
# 339   0.401  0.710  0.454   4.80   0.54   2.26  1.26  0.06   1.14
# 433   0.411  0.829  0.497   7.96   0.57   2.43  1.32  0.22   1.38
# 526   0.473  0.768  0.549  11.55   0.43   3.66  1.39  0.11   2.67
# 625   0.449  0.787  0.540  12.23   0.54   3.46  1.17  0.29   1.94
# 722   0.429  0.836  0.497   9.01   0.76   3.61  1.64  0.11   1.36
# 816   0.459  0.757  0.550   9.19   0.60   2.77  1.13  0.31   1.37
# 929   0.430  0.625  0.510   2.24   0.29   2.24  0.71  0.25   0.46
# 1048  0.250  0.500  0.272   0.50   0.21   1.21  0.36  0.00   0.14
# 1160  0.647    NaN  0.647   2.20   0.10   1.70  0.40  0.00   0.80
# 340   0.321  0.600  0.359   2.14   0.95   0.90  0.19  0.10   0.52
# 434   0.458  0.703  0.524   6.56   0.94   2.24  0.50  0.18   1.30
# 527   0.444  0.656  0.479   7.51   1.53   3.36  0.81  0.23   1.90
# 626   0.475  0.799  0.526  13.09   2.18   4.09  0.93  0.48   1.77
# 723   0.434  0.770  0.493  12.22   1.94   4.29  0.87  0.40   1.99
# 817   0.463  0.734  0.514  13.27   2.06   4.37  1.01  0.28   2.06
# 930   0.459  0.672  0.508  17.55   2.20   4.79  1.29  0.24   3.09
# 1049  0.452  0.694  0.513  18.57   1.74   5.14  1.12  0.18   2.57
# 1161  0.457  0.694  0.540  16.47   1.94   4.42  0.83  0.31   2.17
# 1162  0.458  0.713  0.538  15.89   1.97   4.31  0.69  0.28   2.53
# 1163  0.456  0.681  0.542  16.98   1.90   4.52  0.95  0.33   1.86
# 1277  0.434  0.774  0.547  13.60   1.32   4.10  0.91  0.20   1.11
# 1409  0.439  0.793  0.547  20.12   1.36   4.88  1.21  0.30   2.21
# ...     ...    ...    ...    ...    ...    ...   ...   ...    ...
# 932   0.415  0.837  0.529  11.85   0.20   0.95  0.40  0.10   1.05
# 69    0.470  0.677  0.531   9.32   1.43   3.01  2.16  0.47   2.38
# 725   0.472  0.661  0.530  13.49   3.05   5.74  0.76  1.06   2.30
# 819   0.475  0.713  0.536  20.60   2.85   6.16  1.16  1.62   3.22
# 933   0.559  0.733  0.617  26.00   2.74   6.18  0.96  1.62   2.36
# 1051  0.333  0.889  0.420   8.67   2.00   3.33  0.33  1.00   0.33
# 1165  0.575  0.781  0.637  20.38   2.71   6.88  0.95  1.34   2.83
# 1280  0.590  0.805  0.656  25.18   2.25   6.85  0.81  2.06   2.20
# 1414  0.539  0.835  0.617  21.40   2.19   5.92  0.92  1.08   2.83
# 1549  0.557  0.771  0.615  23.12   2.80   6.12  0.63  1.01   2.60
# 1683  0.502  0.792  0.565  25.27   2.54   5.62  0.91  1.92   3.21
# 1840  0.483  0.765  0.541  17.51   2.26   5.55  0.81  0.96   2.38
# 1976  0.577  0.808  0.637  14.24   2.07   2.93  0.34  0.72   1.72
# 2103  0.557  0.739  0.596  11.88   1.72   3.20  0.35  0.57   1.40
# 2231  0.557  0.720  0.595  11.53   1.86   3.71  0.49  0.64   1.32
# 2232  0.543  0.740  0.589  12.00   2.31   4.50  0.56  0.94   1.75
# 2233  0.581  0.678  0.605  10.78   1.17   2.48  0.39  0.17   0.65
# 2373  0.566  0.746  0.599   5.77   1.25   3.02  0.35  0.79   0.90
# 1977  0.608  0.371  0.578   7.93   2.82   4.80  0.98  1.58   0.95
# 2104  0.623  0.418  0.599  13.52   5.43   7.79  1.25  1.62   1.36
# 2234  0.514  0.389  0.504  13.78   5.33   8.13  0.89  1.87   1.46
# 2374  0.521  0.355  0.499  16.22   4.88   9.91  1.47  1.38   1.91
# 2496  0.530  0.386  0.518  13.64   4.26   9.52  1.53  1.10   1.88
# 436   0.449  0.774  0.517  11.15   1.04   2.38  1.02  0.21   2.02
# 529   0.452  0.833  0.541  15.80   1.15   3.24  1.45  0.34   3.23
# 628   0.454  0.817  0.538  16.48   1.33   3.35  1.56  0.42   3.02
# 726   0.406  0.795  0.495  13.60   1.05   2.90  1.24  0.14   2.58
# 820   0.457  0.832  0.541  14.80   1.55   2.91  1.73  0.30   2.62
# 934   0.477  0.838  0.541  13.57   1.22   2.90  1.48  0.10   2.68
# 1052  0.463  0.738  0.532  13.73   1.12   3.16  1.29  0.22   3.12
#
# [100 rows x 17 columns]

# %%
# final_df = round(final_df.groupby(final_df['Player Name']).mean(), 2)
final_df.head()
# Out:
#                Season Start    Age      G       MP    PER   FG%   FT%   TS%  \
# Player Name
# Aaron McKie         2000.18  27.18  56.29  1329.06  11.45  0.42  0.76  0.49
# Al Harrington       2006.80  25.80  56.60  1655.90  13.24  0.43  0.71  0.51
# Al Horford          2012.50  25.50  64.60  2153.50  19.11  0.53  0.75  0.57
# Al Jefferson        2011.00  26.00  67.62  1985.77  20.05  0.50  0.70  0.53
# Allan Houston       2000.00  28.00  69.09  2435.64  14.95  0.44  0.86  0.55
#
#                  PPG  ORB/G  DRB/G   SPG   BPG  TOV/G
# Player Name
# Aaron McKie     6.18   0.57   2.40  1.04  0.19   1.17
# Al Harrington  13.06   1.49   3.84  0.85  0.23   1.77
# Al Horford     14.39   2.27   6.24  0.84  1.24   1.63
# Al Jefferson   15.85   2.26   6.21  0.69  1.20   1.33
# Allan Houston  17.75   0.42   2.47  0.68  0.16   2.11

# %%
print(len(final_df))
# Out:
# 222
